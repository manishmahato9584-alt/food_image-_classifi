# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers

# %%
data_train_path = 'C:/Users/manis/OneDrive/Desktop/food_image _classifi/train'
data_test_path = 'C:/Users/manis/OneDrive/Desktop/food_image _classifi/test'
data_validation_path = 'C:/Users/manis/OneDrive/Desktop/food_image _classifi/validation'

# %%
img_height = 256
img_width = 256

# %%
data_train = data_train.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
data_cat = data_train.class_names
print(data_cat)
# Out:
# ['Bread', 'Dairy product', 'Dessert', 'Egg', 'Fried food', 'Meat', 'Noodles- pasta', 'Rice', 'Soup', 'Vegetable-Fruits', 'seafood']

# %%
data_cat
# Out:
# ['Bread',
#  'Dairy product',
#  'Dessert',
#  'Egg',
#  'Fried food',
#  'Meat',
#  'Noodles- pasta',
#  'Rice',
#  'Soup',
#  'Vegetable-Fruits',
#  'seafood']

# %%
data_validation = data_validation.cache().prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
data_test = tf.keras.utils.image_dataset_from_directory(
    data_test_path,
    image_size=(img_height,img_width),
    shuffle=False,
    batch_size=32,
    validation_split=False
)
# Out:
# Found 162 files belonging to 11 classes.

# %%
plt.figure(figsize=(10,10))

for images, labels in data_train.take(1):
    for i in range(9):
        plt.subplot(3,3,i+1)
        plt.imshow(images[i].numpy().astype('uint8'))
        plt.title(data_cat[labels[i]])
        plt.axis("off")

# %%
from tensorflow.keras.models import Sequential

# %%
data_train
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
num_classes = 11

model = models.Sequential([
    
    layers.Input(shape=(256,256,3)),
    layers.Rescaling(1./255),

    layers.Conv2D(32,3,activation='relu'),
    layers.MaxPooling2D(),

    layers.Conv2D(64,3,activation='relu'),
    layers.MaxPooling2D(),

    layers.Conv2D(128,3,activation='relu'),
    layers.MaxPooling2D(),

    layers.Flatten(),
    layers.Dense(128,activation='relu'),
    layers.Dense(num_classes,activation='softmax')
])

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
epochs_size = 25

history = model.fit(
    data_train,
    validation_data=data_validation,
    epochs=epochs_size
)
# Out:
# Epoch 1/25
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 0.0994 - loss: 5.5017 - val_accuracy: 0.1180 - val_loss: 2.3931
# Epoch 2/25
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.0932 - loss: 2.4092 - val_accuracy: 0.1739 - val_loss: 2.3355
# Epoch 3/25
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.1491 - loss: 2.3595 - val_accuracy: 0.1242 - val_loss: 2.3182
# Epoch 4/25
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.1925 - loss: 2.1997 - val_accuracy: 0.3168 - val_loss: 1.9658
# Epoch 5/25
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.3789 - loss: 1.8787 - val_accuracy: 0.5217 - val_loss: 1.4698
# Epoch 6/25
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.5776 - loss: 1.3872 - val_accuracy: 0.6832 - val_loss: 1.1686
# Epoch 7/25
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7205 - loss: 0.9427 - val_accuracy: 0.8385 - val_loss: 0.6611
# Epoch 8/25
# ...

# %%
epochs_range = range(epochs_size)
plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(epochs_range,history.history['accuracy'],label='train_acc')
plt.plot(epochs_range,history.history['val_accuracy'],label='val_acc')
plt.title('Model Accuracy')

plt.subplot(1,2,2)
plt.plot(epochs_range,history.history['loss'],label='train_loss')
plt.plot(epochs_range,history.history['val_loss'],label='val_loss')
plt.title('loss')
# Out:
# Text(0.5, 1.0, 'loss')

# %%
image = "C:\\Users\\manis\\OneDrive\\Desktop\\food_image _classifi\\Banana.jpg"
imgage = tf.keras.utils.load_img(image, target_size=(img_height,img_width))
img_array = tf.keras.utils.img_to_array(imgage)
img_array = tf.expand_dims(img_array,0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 image = "C:\\Users\\manis\\OneDrive\\Desktop\\food_image _classifi\\Banana.jpg"
# ----> 2 imgage = tf.keras.utils.load_img(image, target_size=(img_height,img_width))
#       3 img_array = tf.keras.utils.img_to_array(imgage)
#       4 img_array = tf.expand_dims(img_array,0)
#
# NameError: name 'tf' is not defined

# %%
predict = model.predict(img_batch)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step

# %%
score = tf.nn.softmax(predict[0])

# %%
"Prediction: {} ({:.2f}% confidence)".format(
        data_cat[np.argmax(score)],
        np.max(score) * 100
    )
# Out:
# veg/Fruit in image is Soup with accuracy of 20.57%

# %%
model.save('image_classify.keras')
